# %%
import sys
import torch
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split

sys.path.append('..')
sys.path.append('../classes/')
sys.path.append('../data/')
sys.path.append('../model_weights/')

from utilities import *
from classes.ClockDataset import *
from classes.MinutesDistance import *
from classes.Models import *

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device.")
# Out:
# Using cuda device.

# %% [markdown]
# <h4>Load data and labels</h4>

# %%
# Load data and add sine and cosine transform to labels
data, labels = load_data('../data')
labels = transform_labels(labels)
print(f"data: {data.shape}, labels: {labels.shape}")

# Choose image samples for plots
samples = []
sample_labels = []
for i in range(4):
    label = i+2550
    sample_labels.append(str(int(labels[label][0].item()))+":"+str(int(labels[label][1].item())))
    img_arr = (data[label].numpy().squeeze(axis=0)*255).astype(np.uint8)
    samples.append(img_arr)

# Plot image samples
font = {'size': 22}
plt.rc('font', **font)
fig, axis = plt.subplots(1,4, figsize=(20,12))
for i in range(4):
    axis[i].imshow(samples[i], cmap="gray")
    axis[i].set_xlabel(sample_labels[i], labelpad=10)
for ax in axis:
    ax.set_xticks([])
    ax.set_yticks([])
# Out:
# data: torch.Size([18000, 1, 150, 150]), labels: torch.Size([18000, 6])

# %% [markdown]
# <br/>
# <h3>Dataset creation</h3>

# %%
# split test set as to not apply data augmentation
test_data, test_labels = data[:500,:], labels[:500,:]
data, labels = data[500:,:], labels[500:,:]

# Create main dataset
clock_dataset = ClockDataset(data, labels, transform=True)
clock_test_datset = ClockDataset(test_data, test_labels, 
                                transform=False)

train_data, val_data = random_split(clock_dataset, 
                                    [16500,1000])
# Split dataset into train, test and validation sets
train_data_loader = DataLoader(train_data, batch_size=64)
val_data_loader = DataLoader(val_data, batch_size=64)
test_data_loader = DataLoader(clock_test_datset, batch_size=64)

# print shapes of batches (channels first)
for X, y in train_data:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([1, 150, 150])
# Shape of y: torch.Size([6]) torch.float32

# %% [markdown]
# <br/>
# <h3>Model creation</h3>

# %%
model = NN_regression(input_channels=1,h=150,w=150, n_outputs=4).to(device)
loss = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# <h4>Main model training step</h4>

# %%
epochs = 200
patience = 10
weights_name = None
approach = "periodic_labels"
# Main training loop
curr_patience = 0
train_losses = []
eval_losses = []
mean_test_loss = np.inf
print("\n~~~Starting training~~~\n")
start_time = time.time()
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    # Training step
    train_l = train(train_data_loader, model, loss, 
                    optimizer, device, approach)
    train_mean = torch.mean(train_l)
    train_losses.append(train_mean)
    print(f"Train loss: {train_mean:>7f}")

    # Evaluation step
    eval_l = evaluate(val_data_loader, model, loss, device, approach)
    eval_mean = torch.mean(eval_l)
    eval_losses.append(eval_mean)
    print(f"Test avg loss: {eval_mean:>8f}")

    # Save new weights if they are better
    if eval_mean < mean_test_loss:
        curr_patience = 0
        if weights_name != None: 
            print("Saving new best weights.")
            mean_test_loss = eval_mean
            torch.save(model.state_dict(), "model_weights/"+weights_name)
        curr_patience = 0
    print()

    # Stop training if patience expired
    if curr_patience >= patience:
        print(f"No new best weights found after {patience} iterations.")
        break
    curr_patience += 1

end_time = time.time()
print(f"Training finished in {np.round(end_time-start_time, 3)} seconds.")
# Out:
# ~~~Starting training~~~
#
# Epoch 1
# -------------------------------
# Train loss: 0.499952
# Test avg loss: 0.498422
#
# Epoch 2
# -------------------------------
# Train loss: 0.498167
# Test avg loss: 0.494734
#
# Epoch 3
# -------------------------------
# Train loss: 0.402083
# Test avg loss: 0.293506
#
# Epoch 4
# -------------------------------
# Train loss: 0.305261
# Test avg loss: 0.272695
#
# Epoch 5
# -------------------------------
# Train loss: 0.289831
# Test avg loss: 0.260153
#
# Epoch 6
# -------------------------------
# Train loss: 0.277900
# Test avg loss: 0.247549
#
# Epoch 7
# -------------------------------
# Train loss: 0.264658
# Test avg loss: 0.233070
#
# Epoch 8
# -------------------------------
# Train loss: 0.246114
# Test avg loss: 0.202394
#
# Epoch 9
# -------------------------------
# Train loss: 0.221532
# Test avg loss: 0.175313
#
# Epoch 10
# -------------------------------
# Train loss: 0.195293
# Test avg loss: 0.143364
#
# Epoch 11
# -------------------------------
# Train loss: 0.171703
# Test avg loss: 0.118175
#
# Epoch 12
# -------------------------------
# Train loss: 0.153664
# Test avg loss: 0.105266
#
# Epoch 13
# -------------------------------
# Train loss: 0.140729
# Test avg loss: 0.094397
#
# Epoch 14
# -------------------------------
# Train loss: 0.130478
# Test avg loss: 0.085340
#
# Epoch 15
# -------------------------------
# Train loss: 0.120593
# Test avg loss: 0.073954
#
# Epoch 16
# -------------------------------
# Train loss: 0.112203
# Test avg loss: 0.073700
#
# Epoch 17
# -------------------------------
# Train loss: 0.107019
# Test avg loss: 0.067165
#
# Epoch 18
# -------------------------------
# Train loss: 0.102393
# Test avg loss: 0.062129
#
# Epoch 19
# -------------------------------
# Train loss: 0.096718
# Test avg loss: 0.055849
#
# Epoch 20
# -------------------------------
# Train loss: 0.092671
# Test avg loss: 0.052961
#
# Epoch 21
# -------------------------------
# Train loss: 0.089502
# Test avg loss: 0.053113
#
# Epoch 22
# -------------------------------
# Train loss: 0.086204
# Test avg loss: 0.053417
#
# Epoch 23
# -------------------------------
# Train loss: 0.083444
# Test avg loss: 0.046863
#
# Epoch 24
# -------------------------------
# Train loss: 0.079636
# Test avg loss: 0.043747
#
# Epoch 25
# -------------------------------
# Train loss: 0.078676
# Test avg loss: 0.040762
#
# Epoch 26
# -------------------------------
# Train loss: 0.076382
# Test avg loss: 0.041334
#
# Epoch 27
# -------------------------------
# Train loss: 0.073613
# Test avg loss: 0.039445
#
# Epoch 28
# -------------------------------
# Train loss: 0.071180
# Test avg loss: 0.038517
#
# Epoch 29
# -------------------------------
# Train loss: 0.070974
# Test avg loss: 0.036491
#
# Epoch 30
# -------------------------------
# Train loss: 0.069305
# Test avg loss: 0.038352
#
# Epoch 31
# -------------------------------
# Train loss: 0.067671
# Test avg loss: 0.034532
#
# Epoch 32
# -------------------------------
# Train loss: 0.065145
# Test avg loss: 0.035001
#
# Epoch 33
# -------------------------------
# Train loss: 0.064205
# Test avg loss: 0.034584
#
# Epoch 34
# -------------------------------
# Train loss: 0.064397
# Test avg loss: 0.031541
#
# Epoch 35
# -------------------------------
# Train loss: 0.062568
# Test avg loss: 0.036357
#
# Epoch 36
# -------------------------------
# Train loss: 0.061600
# Test avg loss: 0.032704
#
# Epoch 37
# -------------------------------
# Train loss: 0.060462
# Test avg loss: 0.029831
#
# Epoch 38
# -------------------------------
# Train loss: 0.058356
# Test avg loss: 0.028527
#
# Epoch 39
# -------------------------------
# Train loss: 0.058184
# Test avg loss: 0.026813
#
# Epoch 40
# -------------------------------
# Train loss: 0.057272
# Test avg loss: 0.026036
#
# Epoch 41
# -------------------------------
# Train loss: 0.055718
# Test avg loss: 0.028010
#
# Epoch 42
# -------------------------------
# Train loss: 0.055068
# Test avg loss: 0.024483
#
# Epoch 43
# -------------------------------
# Train loss: 0.054274
# Test avg loss: 0.025355
#
# Epoch 44
# -------------------------------
# Train loss: 0.053350
# Test avg loss: 0.025431
#
# Epoch 45
# -------------------------------
# Train loss: 0.051862
# Test avg loss: 0.023262
#
# Epoch 46
# -------------------------------
# Train loss: 0.052661
# Test avg loss: 0.025127
#
# Epoch 47
# -------------------------------
# Train loss: 0.051077
# Test avg loss: 0.025050
#
# Epoch 48
# -------------------------------
# Train loss: 0.051284
# Test avg loss: 0.024310
#
# Epoch 49
# -------------------------------
# Train loss: 0.050290
# Test avg loss: 0.022476
#
# Epoch 50
# -------------------------------
# Train loss: 0.050145
# Test avg loss: 0.023228
#
# Epoch 51
# -------------------------------
# Train loss: 0.048810
# Test avg loss: 0.021273
#
# Epoch 52
# -------------------------------
# Train loss: 0.048733
# Test avg loss: 0.024591
#
# Epoch 53
# -------------------------------
# Train loss: 0.047565
# Test avg loss: 0.021340
#
# Epoch 54
# -------------------------------
# Train loss: 0.046928
# Test avg loss: 0.021089
#
# Epoch 55
# -------------------------------
# Train loss: 0.046077
# Test avg loss: 0.021392
#
# Epoch 56
# -------------------------------
# Train loss: 0.045717
# Test avg loss: 0.019028
#
# Epoch 57
# -------------------------------
# Train loss: 0.046095
# Test avg loss: 0.020983
#
# Epoch 58
# -------------------------------
# Train loss: 0.045427
# Test avg loss: 0.020490
#
# Epoch 59
# -------------------------------
# Train loss: 0.045296
# Test avg loss: 0.021736
#
# Epoch 60
# -------------------------------
# Train loss: 0.044274
# Test avg loss: 0.019744
#
# Epoch 61
# -------------------------------
# Train loss: 0.043711
# Test avg loss: 0.019467
#
# Epoch 62
# -------------------------------
# Train loss: 0.043679
# Test avg loss: 0.020691
#
# Epoch 63
# -------------------------------
# Train loss: 0.043829
# Test avg loss: 0.019800
#
# Epoch 64
# -------------------------------

# %%
# Plot losses
train_losses = np.vstack(train_losses)
test_losses = np.vstack(eval_losses)

plt.plot(train_losses, label="train")
plt.plot(test_losses, label="evaluate")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.title("periodic labels approach")
plt.show()

# %% [markdown]
# <h4>Test our model with the unseen data in the test data set</h4>

# %%
# make predictions
predictions = predict(test_data_loader, model, loss, device, approach)

# calculate and print common sense error
cse = MinutesDistance()
cse_error = cse.minutes_loss(torch.FloatTensor(predictions),
                torch.FloatTensor(test_labels[:,:2]))

print(f"Common sense error on test dataset: {np.round(cse_error.numpy(),3)}")
# Out:
# Avg evaluation loss of best weights: 0.498646
#
# Common sense error on test dataset: 195.63400268554688
