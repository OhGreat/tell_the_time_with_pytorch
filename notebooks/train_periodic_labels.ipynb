# %%
import sys
import torch
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split

sys.path.append('..')
sys.path.append('../classes/')
sys.path.append('../data/')
sys.path.append('../model_weights/')

from utilities import *
from classes.ClockDataset import *
from classes.MinutesDistance import *
from classes.Models import *

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device.")
# Out:
# Using cuda device.

# %% [markdown]
# <h4>Load data and labels</h4>

# %%
# Load data and add sine and cosine transform to labels
data, labels = load_data('../data')
labels = transform_labels(labels)
print(f"data: {data.shape}, labels: {labels.shape}")

# Choose image samples for plots
samples = []
sample_labels = []
for i in range(4):
    label = i+2550
    sample_labels.append(str(int(labels[label][0].item()))+":"+str(int(labels[label][1].item())))
    img_arr = (data[label].numpy().squeeze(axis=0)*255).astype(np.uint8)
    samples.append(img_arr)

# Plot image samples
font = {'size': 22}
plt.rc('font', **font)
fig, axis = plt.subplots(1,4, figsize=(20,12))
for i in range(4):
    axis[i].imshow(samples[i], cmap="gray")
    axis[i].set_xlabel(sample_labels[i], labelpad=10)
for ax in axis:
    ax.set_xticks([])
    ax.set_yticks([])
# Out:
# data: torch.Size([18000, 1, 150, 150]), labels: torch.Size([18000, 6])

# %% [markdown]
# <br/>
# <h3>Dataset creation</h3>

# %%
# split test set as to not apply data augmentation
test_data, test_labels = data[:500,:], labels[:500,:]
data, labels = data[500:,:], labels[500:,:]

# Create main dataset
clock_dataset = ClockDataset(data, labels, transform=True)
clock_test_datset = ClockDataset(test_data, test_labels, 
                                transform=False)

train_data, val_data = random_split(clock_dataset, 
                                    [16500,1000])
# Split dataset into train, test and validation sets
train_data_loader = DataLoader(train_data, batch_size=64)
val_data_loader = DataLoader(val_data, batch_size=64)
test_data_loader = DataLoader(clock_test_datset, batch_size=64)

# print shapes of batches (channels first)
for X, y in train_data_loader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 150, 150])
# Shape of y: torch.Size([64, 6]) torch.float32

# %% [markdown]
# <br/>
# <h3>Model creation</h3>

# %%
model = NN_regression(input_channels=1,h=150,w=150, n_outputs=4).to(device)
loss = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# <h4>Main model training step</h4>

# %%
epochs = 200
patience = 10
weights_name = None
approach = "periodic_labels"
# Main training loop
curr_patience = 0
train_losses = []
eval_losses = []
mean_test_loss = np.inf
temp_best_weights = model.state_dict()
print("\n~~~Starting training~~~\n")
start_time = time.time()
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    # Training step
    train_l = train(train_data_loader, model, loss, 
                    optimizer, device, approach)
    train_mean = torch.mean(train_l)
    train_losses.append(train_mean)
    print(f"Train loss: {train_mean:>7f}")

    # Evaluation step
    eval_l = evaluate(val_data_loader, model, loss, device, approach)
    eval_mean = torch.mean(eval_l)
    eval_losses.append(eval_mean)
    print(f"Test avg loss: {eval_mean:>8f}")

    # Save new weights if they are better
    if eval_mean < mean_test_loss:
        curr_patience = 0
        temp_best_weights = model.state_dict()
        if weights_name != None:
            print("Saving new best weights.")
            mean_test_loss = eval_mean
            torch.save(model.state_dict(), "model_weights/"+weights_name)
    print()

    # Stop training if patience expired
    if curr_patience >= patience:
        print(f"No new best weights found after {patience} iterations.")
        break
    curr_patience += 1

end_time = time.time()
print(f"Training finished in {np.round(end_time-start_time, 3)} seconds.")

# Load best parameters
model.load_state_dict(temp_best_weights)
# Out:
# ~~~Starting training~~~
#
# Epoch 1
# -------------------------------
# Train loss: 0.499815
# Test avg loss: 0.498601
#
# Epoch 2
# -------------------------------
# Train loss: 0.478739
# Test avg loss: 0.394173
#
# Epoch 3
# -------------------------------
# Train loss: 0.330018
# Test avg loss: 0.289135
#
# Epoch 4
# -------------------------------
# Train loss: 0.296209
# Test avg loss: 0.274313
#
# Epoch 5
# -------------------------------
# Train loss: 0.284677
# Test avg loss: 0.264722
#
# Epoch 6
# -------------------------------
# Train loss: 0.273338
# Test avg loss: 0.252188
#
# Epoch 7
# -------------------------------
# Train loss: 0.259721
# Test avg loss: 0.231523
#
# Epoch 8
# -------------------------------
# Train loss: 0.236926
# Test avg loss: 0.194554
#
# Epoch 9
# -------------------------------
# Train loss: 0.209303
# Test avg loss: 0.159321
#
# Epoch 10
# -------------------------------
# Train loss: 0.182014
# Test avg loss: 0.130326
#
# Epoch 11
# -------------------------------
# Train loss: 0.159778
# Test avg loss: 0.110699
#
# Epoch 12
# -------------------------------
# Train loss: 0.143793
# Test avg loss: 0.102192
#
# Epoch 13
# -------------------------------
# Train loss: 0.128002
# Test avg loss: 0.086221
#
# Epoch 14
# -------------------------------
# Train loss: 0.118230
# Test avg loss: 0.076489
#
# Epoch 15
# -------------------------------
# Train loss: 0.110847
# Test avg loss: 0.076052
#
# Epoch 16
# -------------------------------
# Train loss: 0.104379
# Test avg loss: 0.068410
#
# Epoch 17
# -------------------------------
# Train loss: 0.098318
# Test avg loss: 0.063506
#
# Epoch 18
# -------------------------------
# Train loss: 0.093613
# Test avg loss: 0.063570
#
# Epoch 19
# -------------------------------
# Train loss: 0.089776
# Test avg loss: 0.058834
#
# Epoch 20
# -------------------------------
# Train loss: 0.086824
# Test avg loss: 0.053029
#
# Epoch 21
# -------------------------------
# Train loss: 0.083187
# Test avg loss: 0.052326
#
# Epoch 22
# -------------------------------
# Train loss: 0.080340
# Test avg loss: 0.048141
#
# Epoch 23
# -------------------------------
# Train loss: 0.078154
# Test avg loss: 0.049781
#
# Epoch 24
# -------------------------------
# Train loss: 0.076297
# Test avg loss: 0.045194
#
# Epoch 25
# -------------------------------
# Train loss: 0.072877
# Test avg loss: 0.045234
#
# Epoch 26
# -------------------------------
# Train loss: 0.071377
# Test avg loss: 0.042390
#
# Epoch 27
# -------------------------------
# Train loss: 0.068994
# Test avg loss: 0.042389
#
# Epoch 28
# -------------------------------
# Train loss: 0.067726
# Test avg loss: 0.041326
#
# Epoch 29
# -------------------------------
# Train loss: 0.066229
# Test avg loss: 0.036012
#
# Epoch 30
# -------------------------------
# Train loss: 0.064739
# Test avg loss: 0.036295
#
# Epoch 31
# -------------------------------
# Train loss: 0.063676
# Test avg loss: 0.038952
#
# Epoch 32
# -------------------------------
# Train loss: 0.062484
# Test avg loss: 0.031543
#
# Epoch 33
# -------------------------------
# Train loss: 0.061330
# Test avg loss: 0.037112
#
# Epoch 34
# -------------------------------
# Train loss: 0.059698
# Test avg loss: 0.036865
#
# Epoch 35
# -------------------------------
# Train loss: 0.059500
# Test avg loss: 0.033378
#
# Epoch 36
# -------------------------------
# Train loss: 0.057434
# Test avg loss: 0.033997
#
# Epoch 37
# -------------------------------
# Train loss: 0.056611
# Test avg loss: 0.029799
#
# Epoch 38
# -------------------------------
# Train loss: 0.055181
# Test avg loss: 0.033078
#
# Epoch 39
# -------------------------------
# Train loss: 0.054580
# Test avg loss: 0.029022
#
# Epoch 40
# -------------------------------
# Train loss: 0.054020
# Test avg loss: 0.032756
#
# Epoch 41
# -------------------------------
# Train loss: 0.052603
# Test avg loss: 0.030410
#
# Epoch 42
# -------------------------------
# Train loss: 0.052341
# Test avg loss: 0.031501
#
# Epoch 43
# -------------------------------
# Train loss: 0.051592
# Test avg loss: 0.028869
#
# Epoch 44
# -------------------------------
# Train loss: 0.051116
# Test avg loss: 0.028951
#
# Epoch 45
# -------------------------------
# Train loss: 0.049658
# Test avg loss: 0.026449
#
# Epoch 46
# -------------------------------
# Train loss: 0.049829
# Test avg loss: 0.027406
#
# Epoch 47
# -------------------------------
# Train loss: 0.049421
# Test avg loss: 0.026747
#
# Epoch 48
# -------------------------------
# Train loss: 0.049251
# Test avg loss: 0.024272
#
# Epoch 49
# -------------------------------
# Train loss: 0.047251
# Test avg loss: 0.025916
#
# Epoch 50
# -------------------------------
# Train loss: 0.047668
# Test avg loss: 0.024582
#
# Epoch 51
# -------------------------------
# Train loss: 0.046896
# Test avg loss: 0.023437
#
# Epoch 52
# -------------------------------
# Train loss: 0.045882
# Test avg loss: 0.023931
#
# Epoch 53
# -------------------------------
# Train loss: 0.045150
# Test avg loss: 0.022197
#
# Epoch 54
# -------------------------------
# Train loss: 0.044553
# Test avg loss: 0.023354
#
# Epoch 55
# -------------------------------
# Train loss: 0.044810
# Test avg loss: 0.023074
#
# Epoch 56
# -------------------------------
# Train loss: 0.044352
# Test avg loss: 0.021808
#
# Epoch 57
# -------------------------------
# Train loss: 0.044151
# Test avg loss: 0.022048
#
# Epoch 58
# -------------------------------
# Train loss: 0.043015
# Test avg loss: 0.021157
#
# Epoch 59
# -------------------------------
# Train loss: 0.042892
# Test avg loss: 0.022919
#
# Epoch 60
# -------------------------------
# Train loss: 0.042370
# Test avg loss: 0.021566
#
# Epoch 61
# -------------------------------
# Train loss: 0.042472
# Test avg loss: 0.020257
#
# Epoch 62
# -------------------------------
# Train loss: 0.041216
# Test avg loss: 0.022210
#
# Epoch 63
# -------------------------------
# Train loss: 0.041426
# Test avg loss: 0.019553
#
# Epoch 64
# -------------------------------
# Train loss: 0.040904
# Test avg loss: 0.022540
#
# Epoch 65
# -------------------------------
# Train loss: 0.040711
# Test avg loss: 0.022375
#
# Epoch 66
# -------------------------------
# Train loss: 0.039670
# Test avg loss: 0.021993
#
# Epoch 67
# -------------------------------
# Train loss: 0.040201
# Test avg loss: 0.022775
#
# Epoch 68
# -------------------------------
# Train loss: 0.040381
# Test avg loss: 0.020984
#
# Epoch 69
# -------------------------------
# Train loss: 0.039124
# Test avg loss: 0.020038
#
# Epoch 70
# -------------------------------
# Train loss: 0.039095
# Test avg loss: 0.019227
#
# Epoch 71
# -------------------------------
# Train loss: 0.038530
# Test avg loss: 0.017273
#
# Epoch 72
# -------------------------------
# Train loss: 0.038203
# Test avg loss: 0.018816
#
# Epoch 73
# -------------------------------
# Train loss: 0.038464
# Test avg loss: 0.017901
#
# Epoch 74
# -------------------------------
# Train loss: 0.037555
# Test avg loss: 0.018409
#
# Epoch 75
# -------------------------------
# Train loss: 0.038206
# Test avg loss: 0.017442
#
# Epoch 76
# -------------------------------
# Train loss: 0.037291
# Test avg loss: 0.018403
#
# Epoch 77
# -------------------------------
# Train loss: 0.036594
# Test avg loss: 0.019947
#
# Epoch 78
# -------------------------------
# Train loss: 0.035988
# Test avg loss: 0.018104
#
# Epoch 79
# -------------------------------
# Train loss: 0.036755
# Test avg loss: 0.017985
#
# Epoch 80
# -------------------------------
# Train loss: 0.036602
# Test avg loss: 0.017616
#
# Epoch 81
# -------------------------------
# Train loss: 0.036156
# Test avg loss: 0.017575
#
# Epoch 82
# -------------------------------
# Train loss: 0.035854
# Test avg loss: 0.020583
#
# Epoch 83
# -------------------------------
# Train loss: 0.035505
# Test avg loss: 0.017343
#
# Epoch 84
# -------------------------------
# Train loss: 0.035601
# Test avg loss: 0.017644
#
# Epoch 85
# -------------------------------
# Train loss: 0.035110
# Test avg loss: 0.016807
#
# Epoch 86
# -------------------------------
# Train loss: 0.035484
# Test avg loss: 0.014479
#
# Epoch 87
# -------------------------------
# Train loss: 0.034724
# Test avg loss: 0.015448
#
# Epoch 88
# -------------------------------
# Train loss: 0.034731
# Test avg loss: 0.015177
#
# Epoch 89
# -------------------------------
# Train loss: 0.034282
# Test avg loss: 0.014597
#
# Epoch 90
# -------------------------------
# Train loss: 0.034099
# Test avg loss: 0.015282
#
# Epoch 91
# -------------------------------
# Train loss: 0.033728
# Test avg loss: 0.014634
#
# Epoch 92
# -------------------------------
# Train loss: 0.034006
# Test avg loss: 0.017478
#
# Epoch 93
# -------------------------------
# Train loss: 0.034390
# Test avg loss: 0.015375
#
# Epoch 94
# -------------------------------
# Train loss: 0.033847
# Test avg loss: 0.014788
#
# Epoch 95
# -------------------------------
# Train loss: 0.033251
# Test avg loss: 0.016590
#
# Epoch 96
# -------------------------------
# Train loss: 0.032528
# Test avg loss: 0.015192
#
# Epoch 97
# -------------------------------
# Train loss: 0.032670
# Test avg loss: 0.013235
#
# Epoch 98
# -------------------------------
# Train loss: 0.032772
# Test avg loss: 0.014141
#
# Epoch 99
# -------------------------------
# Train loss: 0.032371
# Test avg loss: 0.018040
#
# Epoch 100
# -------------------------------
# Train loss: 0.032561
# Test avg loss: 0.014810
#
# Epoch 101
# -------------------------------
# Train loss: 0.032660
# Test avg loss: 0.014281
#
# Epoch 102
# -------------------------------
# Train loss: 0.032641
# Test avg loss: 0.014766
#
# Epoch 103
# -------------------------------
# Train loss: 0.031799
# Test avg loss: 0.014066
#
# Epoch 104
# -------------------------------
# Train loss: 0.031555
# Test avg loss: 0.015558
#
# Epoch 105
# -------------------------------
# Train loss: 0.030871
# Test avg loss: 0.014005
#
# Epoch 106
# -------------------------------
# Train loss: 0.031368
# Test avg loss: 0.014911
#
# Epoch 107
# -------------------------------
# Train loss: 0.031753
# Test avg loss: 0.013993
#
# Epoch 108
# -------------------------------
# Train loss: 0.030744
# Test avg loss: 0.014595
#
# Epoch 109
# -------------------------------
# Train loss: 0.031003
# Test avg loss: 0.015199
#
# Epoch 110
# -------------------------------
# Train loss: 0.031224
# Test avg loss: 0.013617
#
# Epoch 111
# -------------------------------
# Train loss: 0.030815
# Test avg loss: 0.013797
#
# Epoch 112
# -------------------------------
# Train loss: 0.030529
# Test avg loss: 0.014927
#
# Epoch 113
# -------------------------------
# Train loss: 0.029963
# Test avg loss: 0.015183
#
# Epoch 114
# -------------------------------
# Train loss: 0.030440
# Test avg loss: 0.012353
#
# Epoch 115
# -------------------------------
# Train loss: 0.029928
# Test avg loss: 0.013971
#
# Epoch 116
# -------------------------------
# Train loss: 0.030495
# Test avg loss: 0.014706
#
# Epoch 117
# -------------------------------
# Train loss: 0.030539
# Test avg loss: 0.013920
#
# Epoch 118
# -------------------------------
# Train loss: 0.029475
# Test avg loss: 0.014086
#
# Epoch 119
# -------------------------------
# Train loss: 0.029906
# Test avg loss: 0.011590
#
# Epoch 120
# -------------------------------
# Train loss: 0.029481
# Test avg loss: 0.013213
#
# Epoch 121
# -------------------------------
# Train loss: 0.029133
# Test avg loss: 0.011126
#
# Epoch 122
# -------------------------------
# Train loss: 0.028931
# Test avg loss: 0.013379
#
# Epoch 123
# -------------------------------
# Train loss: 0.029449
# Test avg loss: 0.012825
#
# Epoch 124
# -------------------------------
# Train loss: 0.029515
# Test avg loss: 0.012707
#
# Epoch 125
# -------------------------------
# Train loss: 0.028554
# Test avg loss: 0.012640
#
# Epoch 126
# -------------------------------
# Train loss: 0.029482
# Test avg loss: 0.011576
#
# Epoch 127
# -------------------------------
# Train loss: 0.028573
# Test avg loss: 0.012191
#
# Epoch 128
# -------------------------------
# Train loss: 0.028685
# Test avg loss: 0.013884
#
# Epoch 129
# -------------------------------
# Train loss: 0.028659
# Test avg loss: 0.013807
#
# Epoch 130
# -------------------------------
# Train loss: 0.028180
# Test avg loss: 0.012497
#
# Epoch 131
# -------------------------------
# Train loss: 0.027975
# Test avg loss: 0.012620
#
# Epoch 132
# -------------------------------
# Train loss: 0.027988
# Test avg loss: 0.013129
#
# Epoch 133
# -------------------------------
# Train loss: 0.028096
# Test avg loss: 0.014553
#
# Epoch 134
# -------------------------------
# Train loss: 0.028884
# Test avg loss: 0.011764
#
# Epoch 135
# -------------------------------
# Train loss: 0.027956
# Test avg loss: 0.011305
#
# Epoch 136
# -------------------------------
# Train loss: 0.027381
# Test avg loss: 0.012347
#
# Epoch 137
# -------------------------------
# Train loss: 0.027720
# Test avg loss: 0.012474
#
# Epoch 138
# -------------------------------
# Train loss: 0.027420
# Test avg loss: 0.010953
#
# Epoch 139
# -------------------------------
# Train loss: 0.027655
# Test avg loss: 0.013491
#
# Epoch 140
# -------------------------------
# Train loss: 0.027433
# Test avg loss: 0.011529
#
# Epoch 141
# -------------------------------
# Train loss: 0.028304
# Test avg loss: 0.012111
#
# Epoch 142
# -------------------------------
# Train loss: 0.026902
# Test avg loss: 0.009966
#
# Epoch 143
# -------------------------------
# Train loss: 0.027266
# Test avg loss: 0.012492
#
# Epoch 144
# -------------------------------
# Train loss: 0.026708
# Test avg loss: 0.010791
#
# Epoch 145
# -------------------------------
# Train loss: 0.026832
# Test avg loss: 0.010072
#
# Epoch 146
# -------------------------------
# Train loss: 0.026744
# Test avg loss: 0.011104
#
# Epoch 147
# -------------------------------
# Train loss: 0.026724
# Test avg loss: 0.010677
#
# Epoch 148
# -------------------------------
# Train loss: 0.026292
# Test avg loss: 0.010948
#
# Epoch 149
# -------------------------------
# Train loss: 0.026346
# Test avg loss: 0.011818
#
# Epoch 150
# -------------------------------
# Train loss: 0.026526
# Test avg loss: 0.012108
#
# Epoch 151
# -------------------------------
# Train loss: 0.026589
# Test avg loss: 0.009791
#
# Epoch 152
# -------------------------------
# Train loss: 0.026071
# Test avg loss: 0.011598
#
# Epoch 153
# -------------------------------
# Train loss: 0.026178
# Test avg loss: 0.010003
#
# Epoch 154
# -------------------------------
# Train loss: 0.026027
# Test avg loss: 0.009856
#
# Epoch 155
# -------------------------------
# Train loss: 0.026122
# Test avg loss: 0.009720
#
# Epoch 156
# -------------------------------
# Train loss: 0.026220
# Test avg loss: 0.010366
#
# Epoch 157
# -------------------------------
# Train loss: 0.026114
# Test avg loss: 0.010604
#
# Epoch 158
# -------------------------------
# Train loss: 0.025468
# Test avg loss: 0.010645
#
# Epoch 159
# -------------------------------
# Train loss: 0.025799
# Test avg loss: 0.010420
#
# Epoch 160
# -------------------------------
# Train loss: 0.025623
# Test avg loss: 0.011862
#
# Epoch 161
# -------------------------------
# Train loss: 0.025789
# Test avg loss: 0.010354
#
# Epoch 162
# -------------------------------
# Train loss: 0.025839
# Test avg loss: 0.010366
#
# Epoch 163
# -------------------------------
# Train loss: 0.025709
# Test avg loss: 0.011108
#
# Epoch 164
# -------------------------------
# Train loss: 0.025353
# Test avg loss: 0.009527
#
# Epoch 165
# -------------------------------
# Train loss: 0.025336
# Test avg loss: 0.011152
#
# Epoch 166
# -------------------------------
# Train loss: 0.025134
# Test avg loss: 0.011151
#
# Epoch 167
# -------------------------------
# Train loss: 0.025445
# Test avg loss: 0.010020
#
# Epoch 168
# -------------------------------
# Train loss: 0.025913
# Test avg loss: 0.010701
#
# Epoch 169
# -------------------------------
# Train loss: 0.025202
# Test avg loss: 0.009409
#
# Epoch 170
# -------------------------------
# Train loss: 0.024979
# Test avg loss: 0.009766
#
# Epoch 171
# -------------------------------
# Train loss: 0.024840
# Test avg loss: 0.009308
#
# Epoch 172
# -------------------------------
# Train loss: 0.024831
# Test avg loss: 0.009828
#
# Epoch 173
# -------------------------------
# Train loss: 0.025125
# Test avg loss: 0.010263
#
# Epoch 174
# -------------------------------
# Train loss: 0.025154
# Test avg loss: 0.009523
#
# Epoch 175
# -------------------------------
# Train loss: 0.024232
# Test avg loss: 0.009950
#
# Epoch 176
# -------------------------------
# Train loss: 0.024240
# Test avg loss: 0.009328
#
# Epoch 177
# -------------------------------
# Train loss: 0.024713
# Test avg loss: 0.009189
#
# Epoch 178
# -------------------------------
# Train loss: 0.024418
# Test avg loss: 0.010449
#
# Epoch 179
# -------------------------------
# Train loss: 0.024183
# Test avg loss: 0.009133
#
# Epoch 180
# -------------------------------
# Train loss: 0.024587
# Test avg loss: 0.007991
#
# Epoch 181
# -------------------------------
# Train loss: 0.024544
# Test avg loss: 0.009512
#
# Epoch 182
# -------------------------------
# Train loss: 0.024242
# Test avg loss: 0.009653
#
# Epoch 183
# -------------------------------
# Train loss: 0.024258
# Test avg loss: 0.009940
#
# Epoch 184
# -------------------------------
# Train loss: 0.024226
# Test avg loss: 0.011106
#
# Epoch 185
# -------------------------------
# Train loss: 0.024376
# Test avg loss: 0.009127
#
# Epoch 186
# -------------------------------
# Train loss: 0.023891
# Test avg loss: 0.008977
#
# Epoch 187
# -------------------------------
# Train loss: 0.023588
# Test avg loss: 0.009290
#
# Epoch 188
# -------------------------------
# Train loss: 0.024009
# Test avg loss: 0.008105
#
# Epoch 189
# -------------------------------
# Train loss: 0.023602
# Test avg loss: 0.009219
#
# Epoch 190
# -------------------------------
# Train loss: 0.024022
# Test avg loss: 0.009186
#
# Epoch 191
# -------------------------------
# Train loss: 0.023938
# Test avg loss: 0.008953
#
# Epoch 192
# -------------------------------
# Train loss: 0.023694
# Test avg loss: 0.011356
#
# Epoch 193
# -------------------------------
# Train loss: 0.023543
# Test avg loss: 0.008994
#
# Epoch 194
# -------------------------------
# Train loss: 0.023840
# Test avg loss: 0.008833
#
# Epoch 195
# -------------------------------
# Train loss: 0.023259
# Test avg loss: 0.008167
#
# Epoch 196
# -------------------------------
# Train loss: 0.023403
# Test avg loss: 0.008376
#
# Epoch 197
# -------------------------------
# Train loss: 0.023414
# Test avg loss: 0.008860
#
# Epoch 198
# -------------------------------
# Train loss: 0.023185
# Test avg loss: 0.007704
#
# Epoch 199
# -------------------------------
# Train loss: 0.023295
# Test avg loss: 0.008622
#
# Epoch 200
# -------------------------------
# Train loss: 0.023193
# Test avg loss: 0.009030
#
# Training finished in 4420.249 seconds.
# <All keys matched successfully>

# %%
# Plot losses
train_losses = np.vstack(train_losses)
test_losses = np.vstack(eval_losses)

plt.plot(train_losses, label="train")
plt.plot(test_losses, label="evaluate")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.title("periodic labels approach")
plt.show()

# %% [markdown]
# <h4>Test our model with the unseen data in the test data set</h4>

# %%
# make predictions
predictions = predict(test_data_loader, model, loss, device, approach)

# calculate and print common sense error
cse = MinutesDistance()
cse_error = cse.minutes_loss(torch.FloatTensor(predictions),
                torch.FloatTensor(test_labels[:,:2]))

print(f"Common sense error on test dataset: {np.round(cse_error.numpy(),3)}")
# Out:
# Avg evaluation loss of best weights: 0.011940
#
# Common sense error on test dataset: 9.758000373840332
